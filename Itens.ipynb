# %% [markdown]
# Swords

# %%
swords_dd = {
    "Swords": {
        "Shortsword": {
            "Damage": "1d6",
            "Value": "10 gp",
            "Weight_lb": 2,
            "Weight_kg": 0.91,
            "Properties": ["Finesse", "Light"]
        },
        "Longsword": {
            "Damage": "1d8",
            "Value": "15 gp",
            "Weight_lb": 3,
            "Weight_kg": 1.36,
            "Properties": ["Versatile (1d10)"]
        },
        "Greatsword": {
            "Damage": "2d6",
            "Value": "50 gp",
            "Weight_lb": 6,
            "Weight_kg": 2.72,
            "Properties": ["Heavy", "Two-handed"]
        },
        "Scimitar": {
            "Damage": "1d6",
            "Value": "25 gp",
            "Weight_lb": 3,
            "Weight_kg": 1.36,
            "Properties": ["Finesse", "Light"]
        },
        "Rapier": {
            "Damage": "1d8",
            "Value": "25 gp",
            "Weight_lb": 2,
            "Weight_kg": 0.91,
            "Properties": ["Finesse"]
        },
        "Falchion": {
            "Damage": "2d4",
            "Value": "25 gp",
            "Weight_lb": 4,
            "Weight_kg": 1.81,
            "Properties": ["Heavy", "Two-handed"]
        },
        "Broadsword": {
            "Damage": "1d8",
            "Value": "20 gp",
            "Weight_lb": 3,
            "Weight_kg": 1.36,
            "Properties": ["Versatile (1d10)"]
        },
        "Bastard Sword": {
            "Damage": "1d10",
            "Value": "35 gp",
            "Weight_lb": 6,
            "Weight_kg": 2.72,
            "Properties": ["Versatile (1d12)"]
        }
    }
}

# %% [markdown]
# Bows

# %%
ranged_weapons_dd = {
    "Ranged Weapons": {
        "Shortbow": {
            "Damage": "1d6",
            "Value": "25 gp",
            "Weight_lb": 2,
            "Weight_kg": 0.91,
            "Properties": ["Ammunition (80/320)", "Ammunition_m (24/97)", "Two-handed"]
        },
        "Longbow": {
            "Damage": "1d8",
            "Value": "50 gp",
            "Weight_lb": 2,
            "Weight_kg": 0.91,
            "Properties": ["Ammunition (150/600)", "Ammunition_m (45/180)", "Heavy", "Two-handed"]
        },
        "Light Crossbow": {
            "Damage": "1d8",
            "Value": "25 gp",
            "Weight_lb": 5,
            "Weight_kg": 2.27,
            "Properties": ["Ammunition (80/320)", "Ammunition_m (24/97)", "Loading", "Two-handed"]
        },
        "Heavy Crossbow": {
            "Damage": "1d10",
            "Value": "50 gp",
            "Weight_lb": 18,
            "Weight_kg": 8.16,
            "Properties": ["Ammunition (100/400)", "Ammunition_m (30/120)", "Heavy", "Loading", "Two-handed"]
        },
        "Hand Crossbow": {
            "Damage": "1d6",
            "Value": "75 gp",
            "Weight_lb": 3,
            "Weight_kg": 1.36,
            "Properties": ["Ammunition (30/120)", "Ammunition_m (9/36)", "Light", "Loading"]
        },
        "Sling": {
            "Damage": "1d4",
            "Value": "1 sp",
            "Weight_lb": 0,
            "Weight_kg": 0,
            "Properties": ["Ammunition (30/120)", "Ammunition_m (9/36)"]
        },
        "Blowgun": {
            "Damage": "1",
            "Value": "10 gp",
            "Weight_lb": 1,
            "Weight_kg": 0.45,
            "Properties": ["Ammunition (25/100)", "Ammunition_m (7/30)", "Loading"]
        }
    }
}

# %% [markdown]
# Armors

# %% [markdown]
# Armor class :
# Sem armadura: 10+dex
#
# Armaduras leves: armadura+dex
#
# Médias: armadura+dex max 2
#
#
# Pesada: armadura

# %%
armor_dd = {
    "Armor": {
        # Light Armor
        "Padded": {
            "AC": 11,
            "Dex_modifier": "AC + Dex",
            "Value": "5 gp",
            "Weight_lb": 8,
            "Weight_kg": 3.63,
            "Properties": ["Light", "Stealth Disadvantage"]
        },
        "Leather": {
            "AC": 11,
            "Dex_modifier": "AC + Dex",
            "Value": "10 gp",
            "Weight_lb": 10,
            "Weight_kg": 4.54,
            "Properties": ["Light"]
        },
        "Studded Leather": {
            "AC": 12,
            "Dex_modifier": "AC + Dex",
            "Value": "45 gp",
            "Weight_lb": 13,
            "Weight_kg": 5.90,
            "Properties": ["Light"]
        },
        # Medium Armor
        "Hide": {
            "AC": 12,
            "Dex_modifier": "AC + Dex (max 2)",
            "Value": "10 gp",
            "Weight_lb": 12,
            "Weight_kg": 5.44,
            "Properties": ["Medium"]
        },
        "Chain Shirt": {
            "AC": 13,
            "Dex_modifier": "AC + Dex (max 2)",
            "Value": "50 gp",
            "Weight_lb": 20,
            "Weight_kg": 9.07,
            "Properties": ["Medium"]
        },
        "Scale Mail": {
            "AC": 14,
            "Dex_modifier": "AC + Dex (max 2)",
            "Value": "50 gp",
            "Weight_lb": 45,
            "Weight_kg": 20.41,
            "Properties": ["Medium", "Stealth Disadvantage"]
        },
        "Breastplate": {
            "AC": 14,
            "Dex_modifier": "AC + Dex (max 2)",
            "Value": "400 gp",
            "Weight_lb": 20,
            "Weight_kg": 9.07,
            "Properties": ["Medium"]
        },
        "Half Plate": {
            "AC": 15,
            "Dex_modifier": "AC + Dex (max 2)",
            "Value": "750 gp",
            "Weight_lb": 40,
            "Weight_kg": 18.14,
            "Properties": ["Medium", "Stealth Disadvantage"]
        },
        # Heavy Armor
        "Ring Mail": {
            "AC": 14,
            "Dex_modifier": "N/A",
            "Value": "30 gp",
            "Weight_lb": 40,
            "Weight_kg": 18.14,
            "Properties": ["Heavy", "Stealth Disadvantage"]
        },
        "Chain Mail": {
            "AC": 16,
            "Dex_modifier": "N/A",
            "Value": "75 gp",
            "Weight_lb": 55,
            "Weight_kg": 24.95,
            "Properties": ["Heavy", "Stealth Disadvantage", "Strength 13"]
        },
        "Splint": {
            "AC": 17,
            "Dex_modifier": "N/A",
            "Value": "200 gp",
            "Weight_lb": 60,
            "Weight_kg": 27.22,
            "Properties": ["Heavy", "Stealth Disadvantage", "Strength 15"]
        },
        "Plate": {
            "AC": 18,
            "Dex_modifier": "N/A",
            "Value": "1500 gp",
            "Weight_lb": 65,
            "Weight_kg": 29.48,
            "Properties": ["Heavy", "Stealth Disadvantage", "Strength 15"]
        },
        # Shields
        "Shield": {
            "AC": 2,
            "Dex_modifier": "N/A",
            "Value": "10 gp",
            "Weight_lb": 6,
            "Weight_kg": 2.72,
            "Properties": ["Shield"]
        }
    }
}

# %% [markdown]
# Ammunition

# %%
ammunition_dd = {
    "Ammunition": {
        "Arrows": {
            "Damage": "1d6",
            "Value": "1 gp per 20",
            "Weight_lb": 1,
            "Weight_kg": 0.45,
            "Properties": ["Ammunition (Range 80/320)", "Ammunition_m (24/97)"]
        },
        "Bolts": {
            "Damage": "1d8",
            "Value": "1 gp per 20",
            "Weight_lb": 1,
            "Weight_kg": 0.45,
            "Properties": ["Ammunition (Range 100/400)", "Ammunition_m (30/120)"]
        },
        "Blowgun Needles": {
            "Damage": "1",
            "Value": "1 gp per 50",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Properties": ["Ammunition (Range 25/100)", "Ammunition_m (7/30)"]
        },
        "Sling Bullets": {
            "Damage": "1d4",
            "Value": "1 sp per 20",
            "Weight_lb": 1,
            "Weight_kg": 0.45,
            "Properties": ["Ammunition (Range 30/120)", "Ammunition_m (9/36)"]
        }
    }
}

# %% [markdown]
# Potions

# %%
potions_dd = {
    "Potions": {
        "Potion of Healing": {
            "Effect": "Heals HP",
            "Roll": "2d4+2",
            "Value": "50 gp",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Usage": "Drink to restore health"
        },
        "Potion of Greater Healing": {
            "Effect": "Heals HP",
            "Roll": "4d4+4",
            "Value": "100 gp",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Usage": "Drink to restore more health"
        },
        "Potion of Superior Healing": {
            "Effect": "Heals HP",
            "Roll": "8d4+8",
            "Value": "500 gp",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Usage": "Drink to restore a lot of health"
        },
        "Potion of Ultimate Healing": {
            "Effect": "Heals HP",
            "Roll": "10d4+20",
            "Value": "1,000 gp",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Usage": "Drink to fully restore health"
        },
        "Potion of Invisibility": {
            "Effect": "Grants invisibility",
            "Value": "2,000 gp",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Usage": "Drink to become invisible"
        },
        "Potion of Flying": {
            "Effect": "Grants the ability to fly",
            "Duration": "1 hour",
            "Value": "4,000 gp",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Usage": "Drink to gain the ability to fly"
        },
        "Potion of Speed": {
            "Effect": "Grants the effects of the Haste spell",
            "Duration": "1 minute",
            "Value": "2,500 gp",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Usage": "Drink to gain extra speed and actions"
        },
        "Potion of Resistance": {
            "Effect": "Grants resistance to a damage type",
            "Value": "1,000 gp",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Usage": "Drink to gain resistance to a specific damage type"
        },
        "Potion of Climbing": {
            "Effect": "Grants climbing speed equal to walking speed",
            "Duration": "1 hour",
            "Value": "200 gp",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Usage": "Drink to climb surfaces more easily"
        },
        "Potion of Water Breathing": {
            "Effect": "Allows breathing underwater",
            "Duration": "1 hour",
            "Value": "200 gp",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Usage": "Drink to breathe underwater"
        },
        "Potion of Vitality": {
            "Effect": "Restores hit points and cures diseases",
            "Value": "1,500 gp",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Usage": "Drink to restore health and remove diseases"
        },
        "Potion of Longevity": {
            "Effect": "Decreases age by 1d10 years",
            "Value": "10,000 gp",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Usage": "Drink to reduce age"
        },
        "Potion of Mind Reading": {
            "Effect": "Allows telepathic communication and reading thoughts",
            "Duration": "1 hour",
            "Value": "1,000 gp",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Usage": "Drink to read minds and communicate telepathically"
        },
        "Potion of Invisibility": {
            "Effect": "Grants invisibility",
            "Duration": "1 hour",
            "Value": "2,000 gp",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Usage": "Drink to become invisible"
        },
        "Potion of Growth": {
            "Effect": "Increases size and strength",
            "Duration": "1 minute",
            "Value": "1,000 gp",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Usage": "Drink to grow in size and strength"
        }
    }
}

# %% [markdown]
# Magic Itens

# %%
melee_magic_weapons_dd = {
    "Melee Magic Weapons": {
        " +1 Longsword": {
            "Damage": "1d8 slashing",
            "Bonus": "+1 to attack and damage rolls",
            "Value": "2,000 gp",
            "Weight_lb": 3,
            "Weight_kg": 1.36,
            "Properties": ["Requires Attunement"]
        },
        "Flame Tongue": {
            "Damage": "1d6 slashing + 2d6 fire",
            "Bonus": "+1 to attack and damage rolls",
            "Value": "50,000 gp",
            "Weight_lb": 3,
            "Weight_kg": 1.36,
            "Properties": ["Requires Attunement", "Fire damage"]
        },
        "Frost Brand": {
            "Damage": "1d6 slashing + 1d6 cold",
            "Bonus": "+1 to attack and damage rolls",
            "Value": "25,000 gp",
            "Weight_lb": 3,
            "Weight_kg": 1.36,
            "Properties": ["Requires Attunement", "Cold damage"]
        },
        "Sun Blade": {
            "Damage": "1d8 radiant",
            "Bonus": "+2 to attack and damage rolls",
            "Value": "80,000 gp",
            "Weight_lb": 3,
            "Weight_kg": 1.36,
            "Properties": ["Requires Attunement", "Radiant damage"]
        },
        "Vorpal Sword": {
            "Damage": "2d6 slashing",
            "Bonus": "+3 to attack and damage rolls",
            "Value": "50,000 gp",
            "Weight_lb": 3,
            "Weight_kg": 1.36,
            "Properties": ["Requires Attunement", "Vorpal"]
        },
        "Dagger of Venom": {
            "Damage": "1d4 piercing + 1d4 poison",
            "Bonus": "+1 to attack and damage rolls",
            "Value": "2,000 gp",
            "Weight_lb": 1,
            "Weight_kg": 0.45,
            "Properties": ["Requires Attunement", "Poison damage"]
        },
        "Holy Avenger": {
            "Damage": "1d8 slashing + 2d10 radiant",
            "Bonus": "+3 to attack and damage rolls",
            "Value": "100,000 gp",
            "Weight_lb": 3,
            "Weight_kg": 1.36,
            "Properties": ["Requires Attunement by a Paladin", "Radiant damage"]
        },
        "Life Drinker": {
            "Damage": "1d8 necrotic",
            "Bonus": "+1 to attack and damage rolls",
            "Value": "15,000 gp",
            "Weight_lb": 3,
            "Weight_kg": 1.36,
            "Properties": ["Requires Attunement", "Necrotic damage"]
        },
        "Sword of Sharpness": {
            "Damage": "2d6 slashing",
            "Bonus": "+3 to attack and damage rolls",
            "Value": "30,000 gp",
            "Weight_lb": 3,
            "Weight_kg": 1.36,
            "Properties": ["Requires Attunement", "Sharpness"]
        },
        "Wyrmwood Staff": {
            "Damage": "1d6 bludgeoning",
            "Bonus": "+2 to attack and damage rolls",
            "Value": "12,000 gp",
            "Weight_lb": 3,
            "Weight_kg": 1.36,
            "Properties": ["Requires Attunement by a Sorcerer or Wizard"]
        },
        "Staff of Power": {
            "Damage": "1d6 bludgeoning",
            "Bonus": "+2 to attack and damage rolls",
            "Value": "50,000 gp",
            "Weight_lb": 4,
            "Weight_kg": 1.81,
            "Properties": ["Requires Attunement", "Spellcasting"]
        }
    }
}

ranged_magic_weapons_dd = {
    "Ranged Magic Weapons": {
        "Longbow +1": {
            "Damage": "1d8 piercing",
            "Bonus": "+1 to attack and damage rolls",
            "Value": "2,500 gp",
            "Weight_lb": 2,
            "Weight_kg": 0.91,
            "Properties": ["Requires Attunement"]
        },
        "Oathbow": {
            "Damage": "1d8 piercing",
            "Bonus": "+2 to attack and damage rolls",
            "Value": "30,000 gp",
            "Weight_lb": 2,
            "Weight_kg": 0.91,
            "Properties": ["Requires Attunement", "Additional effects against sworn enemies"]
        },
        "Bow of Elvenkind": {
            "Damage": "1d8 piercing",
            "Bonus": "+2 to attack and damage rolls",
            "Value": "10,000 gp",
            "Weight_lb": 2,
            "Weight_kg": 0.91,
            "Properties": ["Requires Attunement", "Enhanced stealth"]
        },
        "Wand of the War Mage +1": {
            "Damage": "1d6 + spell effect",
            "Bonus": "+1 to spell attack rolls",
            "Value": "6,000 gp",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Properties": ["Requires Attunement", "Spellcasting enhancement"]
        },
        "Ioun Stone of Regeneration": {
            "Effect": "Regains 1d4 hit points every 10 minutes",
            "Value": "25,000 gp",
            "Weight_lb": 0.2,
            "Weight_kg": 0.09,
            "Properties": ["Requires Attunement", "Healing effect"]
        }
    }
}

magic_armor_dd = {
    "Magic Armor": {
        " +1 Armor": {
            "AC Bonus": "+1",
            "Value": "2,000 gp",
            "Weight_lb": 20,
            "Weight_kg": 9.07,
            "Properties": ["Requires Attunement"]
        },
        "Cloak of Protection": {
            "AC Bonus": "+1",
            "Saving Throws Bonus": "+1",
            "Value": "4,000 gp",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Properties": ["Requires Attunement"]
        },
        "Shield +1": {
            "AC Bonus": "+1",
            "Value": "2,500 gp",
            "Weight_lb": 6,
            "Weight_kg": 2.72,
            "Properties": ["Requires Attunement"]
        },
        "Armor of Invulnerability": {
            "AC Bonus": "+1",
            "Value": "50,000 gp",
            "Weight_lb": 30,
            "Weight_kg": 13.61,
            "Properties": ["Requires Attunement", "Damage resistance"]
        },
        "Dragon Scale Mail": {
            "AC Bonus": "14 + Dexterity modifier (max 2)",
            "Value": "25,000 gp",
            "Weight_lb": 30,
            "Weight_kg": 13.61,
            "Properties": ["Requires Attunement by a Sorcerer or Wizard", "Resistant to fire damage"]
        }
    }
}

magical_mounts_dd = {
    "Magical Mounts": {
        "Broom of Flying": {
            "Effect": "Allows flying",
            "Value": "5,000 gp",
            "Weight_lb": 2,
            "Weight_kg": 0.91,
            "Properties": ["Requires Attunement", "Flying speed 50 ft"]
        },
        "Horse of a Different Color": {
            "Effect": "Changes color and can be magically summoned",
            "Value": "4,000 gp",
            "Weight_lb": 1,  # Weight is variable as the horse is magical
            "Weight_kg": 0.45,  # Weight is variable as the horse is magical
            "Properties": ["Requires Attunement"]
        },
        "Pegasus": {
            "Effect": "Flying mount",
            "Value": "10,000 gp",
            "Weight_lb": 800,  # Typical weight for a Pegasus is variable
            "Weight_kg": 363.0,  # Weight is variable as the creature is magical
            "Properties": ["Requires Attunement", "Flying speed 120 ft"]
        }
    }
}

magical_utilities_dd = {
    "Magical Utilities": {
        "Bag of Holding": {
            "Effect": "Holds up to 500 lbs of items in a pocket dimension",
            "Value": "2,500 gp",
            "Weight_lb": 5,
            "Weight_kg": 2.27,
            "Properties": ["Requires Attunement"]
        },
        "Amulet of Health": {
            "Effect": "Increases Constitution score to 19",
            "Value": "5,000 gp",
            "Weight_lb": 0.2,
            "Weight_kg": 0.09,
            "Properties": ["Requires Attunement"]
        },
        "Bracers of Defense": {
            "AC Bonus": "+2",
            "Value": "4,000 gp",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Properties": ["Requires Attunement"]
        },
        "Ring of Protection": {
            "AC Bonus": "+1",
            "Saving Throws Bonus": "+1",
            "Value": "8,000 gp",
            "Weight_lb": 0.02,
            "Weight_kg": 0.01,
            "Properties": ["Requires Attunement"]
        },
        "Wand of Magic Missiles": {
            "Effect": "Casts Magic Missile spell",
            "Charges": "7",
            "Value": "10,000 gp",
            "Weight_lb": 0.5,
            "Weight_kg": 0.23,
            "Properties": ["Requires Attunement"]
        }
    }
}
